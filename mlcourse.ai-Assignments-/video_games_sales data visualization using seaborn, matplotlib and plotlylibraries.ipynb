# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
sns.set()
type(sns)
# %config InlineBackend.figure_format= 'svg'

plt.rcParams['figure.figsize']= 12, 6
plt.rcParams['image.cmap']= 'viridis'

# %%
df= pd.read_csv(r"C:\Users\RICHA\Desktop\video_games_sales.csv\video_games_sales.csv").dropna()

# %%
print(df.shape)
# Out:
# (6825, 16)

# %%
df.columns
# Out:
# Index(['Name', 'Platform', 'Year_of_Release', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales', 'Critic_Score',
#        'Critic_Count', 'User_Score', 'User_Count', 'Developer', 'Rating'],
#       dtype='object')

# %%
df.info()
#important to verify if any object is null
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6825 entries, 0 to 16706
# Data columns (total 16 columns):
# Name               6825 non-null object
# Platform           6825 non-null object
# Year_of_Release    6825 non-null float64
# Genre              6825 non-null object
# Publisher          6825 non-null object
# NA_Sales           6825 non-null float64
# EU_Sales           6825 non-null float64
# JP_Sales           6825 non-null float64
# Other_Sales        6825 non-null float64
# Global_Sales       6825 non-null float64
# Critic_Score       6825 non-null float64
# Critic_Count       6825 non-null float64
# User_Score         6825 non-null object
# User_Count         6825 non-null float64
# Developer          6825 non-null object
# Rating             6825 non-null object
# dtypes: float64(9), object(7)
# memory usage: 906.4+ KB

# %%
df.head()
# Out:
#                     Name Platform  Year_of_Release     Genre Publisher  \
# 0             Wii Sports      Wii           2006.0    Sports  Nintendo
# 2         Mario Kart Wii      Wii           2008.0    Racing  Nintendo
# 3      Wii Sports Resort      Wii           2009.0    Sports  Nintendo
# 6  New Super Mario Bros.       DS           2006.0  Platform  Nintendo
# 7               Wii Play      Wii           2006.0      Misc  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 6     11.28      9.14      6.50         2.88         29.80          89.0
# 7     13.96      9.18      2.93         2.84         28.92          58.0
#
#    Critic_Count User_Score  User_Count Developer Rating
# ...

# %%
#Some of the games in this dataset lack ratings; so, let’s filter for only those examples that have all of their values present.

df.dropna()
df.shape
# Out:
# (6825, 16)

# %%
# convert numerical feature of type object to int or float 

df['User_Score'] = df['User_Score'].astype('float64')
df['Year_of_Release'] = df['Year_of_Release'].astype('int64')
df['User_Count'] = df['User_Count'].astype('int64')
df['Critic_Count'] = df['Critic_Count'].astype('int64')

# %%
df.info()
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6825 entries, 0 to 16706
# Data columns (total 16 columns):
# Name               6825 non-null object
# Platform           6825 non-null object
# Year_of_Release    6825 non-null int64
# Genre              6825 non-null object
# Publisher          6825 non-null object
# NA_Sales           6825 non-null float64
# EU_Sales           6825 non-null float64
# JP_Sales           6825 non-null float64
# Other_Sales        6825 non-null float64
# Global_Sales       6825 non-null float64
# Critic_Score       6825 non-null float64
# Critic_Count       6825 non-null int64
# User_Score         6825 non-null float64
# User_Count         6825 non-null int64
# Developer          6825 non-null object
# Rating             6825 non-null object
# dtypes: float64(7), int64(3), object(6)
# memory usage: 906.4+ KB
# (6825, 16)

# %%
df[[x for x in df.columns if 'Sales' in x] + 
   ['Year_of_Release']].groupby('Year_of_Release').sum().plot()

# %%
# `pairplot()` may become very slow with the SVG format
# %config InlineBackend.figure_format = 'png' 
sns.pairplot(df[['Global_Sales', 'Critic_Score', 'Critic_Count', 
                 'User_Score', 'User_Count']]);

# %% [markdown]
# refer for more plots for dat avisualization such as plotly api : https://nbviewer.jupyter.org/github/Yorko/mlcourse_open/blob/master/jupyter_english/topic02_visual_data_analysis/topic2_additional_seaborn_matplotlib_plotly.ipynb?flush_cache=true
