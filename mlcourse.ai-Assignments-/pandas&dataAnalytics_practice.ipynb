# %%
import pandas as pd 
df= pd.read_csv(r"C:\Users\RICHA\Desktop\adult.data.csv\adult.data.csv")

# %%
df
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 0       39         State-gov   77516     Bachelors             13
# 1       50  Self-emp-not-inc   83311     Bachelors             13
# 2       38           Private  215646       HS-grad              9
# 3       53           Private  234721          11th              7
# 4       28           Private  338409     Bachelors             13
# 5       37           Private  284582       Masters             14
# 6       49           Private  160187           9th              5
# 7       52  Self-emp-not-inc  209642       HS-grad              9
# 8       31           Private   45781       Masters             14
# 9       42           Private  159449     Bachelors             13
# 10      37           Private  280464  Some-college             10
# 11      30         State-gov  141297     Bachelors             13
# 12      23           Private  122272     Bachelors             13
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
# age               32561 non-null int64
# workclass         32561 non-null object
# fnlwgt            32561 non-null int64
# education         32561 non-null object
# education-num     32561 non-null int64
# marital-status    32561 non-null object
# occupation        32561 non-null object
# relationship      32561 non-null object
# race              32561 non-null object
# sex               32561 non-null object
# capital-gain      32561 non-null int64
# capital-loss      32561 non-null int64
# hours-per-week    32561 non-null int64
# native-country    32561 non-null object
# salary            32561 non-null object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %% [raw]
# 1. How many men and women (sex feature) are represented in this dataset?

# %%
df['sex'].value_counts()
# Out:
# Male      21790
# Female    10771
# Name: sex, dtype: int64

# %% [raw]
# ans1. Male      21790
# Female    10771

# %% [raw]
# 2.What is the average age (age feature) of women?

# %%
df.loc[df['sex']=='Female', 'age'].mean()
# Out:
# 36.85823043357163

# %% [raw]
# ans2. 36.8

# %% [raw]
# 3. What is the percentage of German citizens (native-country feature)? *

# %%
df['native-country'].count
# Out:
# <bound method Series.count of 0        United-States
# 1        United-States
# 2        United-States
# 3        United-States
# 4                 Cuba
# 5        United-States
# 6              Jamaica
# 7        United-States
# 8        United-States
# 9        United-States
# 10       United-States
# 11               India
# 12       United-States
# 13       United-States
# 14                   ?
# 15              Mexico
# 16       United-States
# 17       United-States
# 18       United-States
# 19       United-States
# 20       United-States
# 21       United-States
# 22       United-States
# 23       United-States
# 24       United-States
# 25       United-States
# 26       United-States
# 27               South
# 28       United-States
# 29       United-States
#              ...
# 32531    United-States
# 32532    United-States
# 32533            Japan
# 32534    United-States
# 32535    United-States
# 32536    United-States
# 32537    United-States
# 32538    United-States
# ...

# %%
df.loc[df['native-country']=='Germany']
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 122     30           Private   77143     Bachelors             13
# 280     22           Private   34918     Bachelors             13
# 767     22           Private  151790  Some-college             10
# 1009    26           Private  109186  Some-college             10
# 1142    59       Federal-gov  212448       HS-grad              9
# 1346    61      Self-emp-inc  134768     Bachelors             13
# 1425    46           Private  134727          11th              7
# 1973    30           Private  111415       HS-grad              9
# 2233    35           Private  178322     Assoc-voc             11
# 2586    26                 ?  152046          11th              7
# 2788    27         State-gov  194773       Masters             14
# 2899    22           Private   24896       HS-grad              9
# 3159    58           Private  235624     Assoc-voc             11
# ...

# %%
df.loc[df['native-country']=='Germany'].describe()
# Out:
#               age         fnlwgt  education-num  capital-gain  capital-loss  \
# count  137.000000     137.000000     137.000000    137.000000    137.000000
# mean    39.255474  189325.313869      10.985401    887.094891     77.978102
# std     12.962065  100809.067728       2.370112   3627.385181    371.502899
# min     18.000000   21306.000000       4.000000      0.000000      0.000000
# 25%     29.000000  116391.000000       9.000000      0.000000      0.000000
# 50%     36.000000  178322.000000      10.000000      0.000000      0.000000
# 75%     47.000000  231604.000000      13.000000      0.000000      0.000000
# max     74.000000  606111.000000      16.000000  27828.000000   1977.000000
#
#        hours-per-week
# count      137.000000
# mean        41.014599
# std         12.328223
# min          6.000000
# 25%         40.000000
# 50%         40.000000
# 75%         50.000000
# max         70.000000

# %%
137/32561
# Out:
# 0.004207487485028101

# %% [raw]
# ans3.0.42

# %% [raw]
# 4. What are the mean and standard deviation of age for those who earn more than 50K per year (salary feature)?

# %%
df[df['salary']=='>50K'].describe()
# Out:
#                age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  7841.000000  7.841000e+03    7841.000000   7841.000000   7841.000000
# mean     44.249841  1.880050e+05      11.611657   4006.142456    195.001530
# std      10.519028  1.025418e+05       2.385129  14570.378951    595.487574
# min      19.000000  1.487800e+04       2.000000      0.000000      0.000000
# 25%      36.000000  1.191010e+05      10.000000      0.000000      0.000000
# 50%      44.000000  1.761010e+05      12.000000      0.000000      0.000000
# 75%      51.000000  2.309590e+05      13.000000      0.000000      0.000000
# max      90.000000  1.226583e+06      16.000000  99999.000000   3683.000000
#
#        hours-per-week
# count     7841.000000
# mean        45.473026
# std         11.012971
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         50.000000
# max         99.000000

# %% [raw]
# ans4.44 +- 10.5 years

# %% [raw]
# 5. What are the mean and standard deviation of age for those who earn less than 50K per year? *

# %%
df[df['salary']=='<=50K'].describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  24720.000000  2.472000e+04   24720.000000  24720.000000  24720.000000
# mean      36.783738  1.903409e+05       9.595065    148.752468     53.142921
# std       14.020088  1.064823e+05       2.436147    963.139307    310.755769
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       25.000000  1.176060e+05       9.000000      0.000000      0.000000
# 50%       34.000000  1.794650e+05       9.000000      0.000000      0.000000
# 75%       46.000000  2.390230e+05      10.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  41310.000000   4356.000000
#
#        hours-per-week
# count    24720.000000
# mean        38.840210
# std         12.318995
# min          1.000000
# 25%         35.000000
# 50%         40.000000
# 75%         40.000000
# max         99.000000

# %% [raw]
# ans5.37 +- 14 years

# %% [raw]
# 6. Is it true that people who earn more than 50K have at least high school education?
# (education – Bachelors, Prof-school, Assoc-acdm, Assoc-voc, Masters or Doctorate feature) *

# %%
df['education'].unique()
# Out:
# array(['Bachelors', 'HS-grad', '11th', 'Masters', '9th', 'Some-college',
#        'Assoc-acdm', 'Assoc-voc', '7th-8th', 'Doctorate', 'Prof-school',
#        '5th-6th', '10th', '1st-4th', 'Preschool', '12th'], dtype=object)

# %%
newdf= df['salary']=='>50K'

# %%
newdf.groupby (df['education']).count()
# Out:
# education
# 10th              933
# 11th             1175
# 12th              433
# 1st-4th           168
# 5th-6th           333
# 7th-8th           646
# 9th               514
# Assoc-acdm       1067
# Assoc-voc        1382
# Bachelors        5355
# Doctorate         413
# HS-grad         10501
# Masters          1723
# Preschool          51
# Prof-school       576
# Some-college     7291
# Name: salary, dtype: int64

# %% [raw]
# ans6.No

# %% [raw]
# 7. Find the maximum age of men of Amer-Indian-Eskimo race.

# %%
new2df= df[df['race']=='Amer-Indian-Eskimo']

# %%
new2df.groupby (df['age']).max()
# Out:
#      age         workclass  fnlwgt     education  education-num  \
# age
# 17    17           Private  130125          11th              7
# 18    18           Private  301867       HS-grad              9
# 19    19  Self-emp-not-inc  243941  Some-college             10
# 20    20           Private  137651  Some-college             10
# 21    21           Private  304302  Some-college             12
# 22    22  Self-emp-not-inc  233955  Some-college             13
# 23    23           Private  306601  Some-college             13
# 24    24           Private  336088  Some-college             10
# 25    25           Private  312338  Some-college             11
# 26    26           Private  151551  Some-college             10
# 27    27         State-gov  221252  Some-college             13
# 28    28           Private  314649  Some-college             11
# 29    29  Self-emp-not-inc  190636  Some-college             10
# 30    30         State-gov  356015  Some-college             11
# ...

# %% [raw]
# ans7.82

# %% [raw]
# 8. Among whom is the proportion of those who earn a lot (>50K) greater: married or single men (marital-status feature)? Consider as married those who have a marital-status starting with Married (Married-civ-spouse, Married-spouse-absent or Married-AF-spouse), the rest are considered bachelors. *

# %%
df['marital-status']
# Out:
# 0                Never-married
# 1           Married-civ-spouse
# 2                     Divorced
# 3           Married-civ-spouse
# 4           Married-civ-spouse
# 5           Married-civ-spouse
# 6        Married-spouse-absent
# 7           Married-civ-spouse
# 8                Never-married
# 9           Married-civ-spouse
# 10          Married-civ-spouse
# 11          Married-civ-spouse
# 12               Never-married
# 13               Never-married
# 14          Married-civ-spouse
# 15          Married-civ-spouse
# 16               Never-married
# 17               Never-married
# 18          Married-civ-spouse
# 19                    Divorced
# 20          Married-civ-spouse
# 21                   Separated
# 22          Married-civ-spouse
# 23          Married-civ-spouse
# 24                    Divorced
# 25          Married-civ-spouse
# 26               Never-married
# 27          Married-civ-spouse
# 28                    Divorced
# 29          Married-civ-spouse
# ...

# %%
df.loc[(df['sex'] == 'Male') & 
     (df['marital-status'].isin(['Married-civ-spouse','Married-spouse-absent','Married-AF-spouse'])), 'salary'].value_counts()
# Out:
# <=50K    7576
# >50K     5965
# Name: salary, dtype: int64

# %%
df.loc[(df['sex'] == 'Male') & 
     (~df['marital-status'].isin(['Married-civ-spouse','Married-spouse-absent','Married-AF-spouse'])), 'salary'].value_counts()
# Out:
# <=50K    7552
# >50K      697
# Name: salary, dtype: int64

# %% [raw]
# ans8. Among married

# %% [raw]
# 9. What is the maximum number of hours a person works per week (hours-per-week feature)? How many people work such a number of hours, and what is the percentage of those who earn a lot (>50K) among them? *

# %%
df['hours-per-week'].max()
# Out:
# 99

# %%
newdf4= df[(df['hours-per-week']==99)]

# %%
 newdf= (df['salary']=='>50K')

# %%
newdf4.count()
# Out:
# age               85
# workclass         85
# fnlwgt            85
# education         85
# education-num     85
# marital-status    85
# occupation        85
# relationship      85
# race              85
# sex               85
# capital-gain      85
# capital-loss      85
# hours-per-week    85
# native-country    85
# salary            85
# dtype: int64

# %%
ndf= newdf4[df['salary']=='>50K']
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
ndf.count()
# Out:
# age               25
# workclass         25
# fnlwgt            25
# education         25
# education-num     25
# marital-status    25
# occupation        25
# relationship      25
# race              25
# sex               25
# capital-gain      25
# capital-loss      25
# hours-per-week    25
# native-country    25
# salary            25
# dtype: int64

# %%
25/85
# Out:
# 0.29411764705882354

# %% [raw]
# ans9.  99 hours/week, 85 people, 29% are rich

# %% [raw]
# 10. Count the average time of work (hours-per-week) for those who
# earn a little and a lot (salary) for each country (native-country). What will these be for Japan?

# %%
import numpy as np
pd.crosstab(df['native-country'], df['salary'], 
            values=df['hours-per-week'], aggfunc=np.mean)
# Out:
# salary                          <=50K       >50K
# native-country
# ?                           40.164760  45.547945
# Cambodia                    41.416667  40.000000
# Canada                      37.914634  45.641026
# China                       37.381818  38.900000
# Columbia                    38.684211  50.000000
# Cuba                        37.985714  42.440000
# Dominican-Republic          42.338235  47.000000
# Ecuador                     38.041667  48.750000
# El-Salvador                 36.030928  45.000000
# England                     40.483333  44.533333
# France                      41.058824  50.750000
# Germany                     39.139785  44.977273
# Greece                      41.809524  50.625000
# Guatemala                   39.360656  36.666667
# Haiti                       36.325000  42.750000
# Holand-Netherlands          40.000000        NaN
# Honduras                    34.333333  60.000000
# Hong                        39.142857  45.000000
# ...

# %% [raw]
# ans10.Japan	41.000000	47.958333
